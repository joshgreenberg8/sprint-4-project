# %% [markdown]
# # Sprint 4 Project
# ## Exploratory Data Analysis
# In this notebook, I will perform some exploratory data analysis on a dataset that I retrieved from Kaggle.com. I will use my findings and my code from this notebook to create and deploy a webapp to share my analysis with others.

# %% [markdown]
# ### Importing libraries and data

# %%
# import libraries
import pandas as pd
import streamlit as st
import plotly_express as px

#load the data into a DataFrame using pandas
games_df = pd.read_csv('../games.csv')
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  object
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  object
#  6   winner          20058 non-null  object
#  7   increment_code  20058 non-null  object
#  8   white_id        20058 non-null  object
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  object
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  object
#  13  opening_eco     20058 non-null  object
#  14  opening_name    20058 non-null  object
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# There are no missing values. Next, check for duplicate rows.

# %%
# checking for duplicate rows
games_df.duplicated().sum()
# Out:
# 429

# %% [markdown]
# There are 429 duplicate rows, further investigation is required.

# %%
# filter for duplicated rows and review them
duplicate_games = games_df[games_df.duplicated()]
duplicate_games
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 950    XRuQPSzH   True  1.503580e+12  1.503580e+12     50         resign
# 1794   x1Svcl0P   True  1.499820e+12  1.499830e+12     59           mate
# 1830   wgIHzqDo   True  1.499710e+12  1.499710e+12    113           mate
# 2554   JrFxlGZo  False  1.489330e+12  1.489330e+12     78           mate
# 2556   ezKACesj  False  1.488840e+12  1.488840e+12     51           mate
# ...         ...    ...           ...           ...    ...            ...
# 20013  Uk0pZCRR   True  1.499532e+12  1.499541e+12     95         resign
# 20014  ZhZm1ol9   True  1.498871e+12  1.498879e+12    109           draw
# 20015  fpqjttDx   True  1.497663e+12  1.497664e+12     42         resign
# 20016  lzPgCJCS   True  1.497660e+12  1.497663e+12    102         resign
# 20017  p391pBJv   True  1.497647e+12  1.497654e+12     97         resign
#
#       winner increment_code         white_id  white_rating         black_id  \
# 950    black           10+0      chess-brahs          2036             cdvh
# 1794   white           10+0  kachess10204542          1171  quantummequanic
# 1830   white           10+0  quantummequanic          1403     barrow-wight
# 2554   black           15+0          sp37578          1309       penguin100
# 2556   white           15+0       penguin100          1393          sp37578
# ...      ...            ...              ...           ...              ...
# 20013  black          45+45        kferapont          2094   moistvonlipwig
# 20014   draw          45+45   moistvonlipwig          2229              mn8
# 20015  black           7+30   waltersafarian          2162   moistvonlipwig
# 20016  black           7+30   moistvonlipwig          2236   waltersafarian
# 20017  white          60+30        i9_4_2001          2268   moistvonlipwig
#
#        black_rating                                              moves  \
# 950            1706  Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...
# 1794           1432  c4 e5 Nc3 Nf6 Nf3 Nc6 g3 d5 cxd5 Nxd5 Bg2 Be6 ...
# 1830           1364  e4 e6 e5 Bc5 d4 Be7 c3 Nh6 Bxh6 gxh6 Qd2 Bg5 f...
# 2554           1393  e4 d5 exd5 Qxd5 Nc3 Qe6+ Qe2 Qc6 d3 Bf5 Qf3 Be...
# 2556           1309  d4 d5 e3 Nf6 Nf3 b6 Nc3 Bb7 Bb5+ Nc6 Ne5 e6 O-...
# ...             ...                                                ...
# 20013          2228  e4 e5 Nf3 Nc6 Bb5 g6 d4 exd4 Bxc6 dxc6 Qxd4 Qx...
# 20014          2220  e4 e5 Nf3 Nc6 Bc4 Bc5 c3 Nf6 d4 exd4 cxd4 Bb4+...
# 20015          2214  d4 Nf6 c4 e6 Nf3 Bb4+ Bd2 a5 e3 O-O Bd3 b6 O-O...
# 20016          2148  e4 g6 Nc3 Bg7 f4 c6 g3 d6 Bg2 e5 fxe5 dxe5 d3 ...
# 20017          2254  e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 d5 exd5 Na5 Bb5+ c6 ...
#
#       opening_eco                                       opening_name  \
# 950           A08             King's Indian Attack: French Variation
# 1794          A29  English Opening: King's English Variation |  F...
# 1830          C00                    French Defense: Steinitz Attack
# 2554          B01      Scandinavian Defense: Mieses-Kotroc Variation
# 2556          D04                    Queen's Pawn Game: Colle System
# ...           ...                                                ...
# 20013         C60                      Ruy Lopez: Fianchetto Defense
# 20014         C54  Italian Game: Classical Variation |  Greco Gam...
# 20015         E11        Bogo-Indian Defense: Wade-Smyslov Variation
# 20016         B06                                     Modern Defense
# 20017         C59  Italian Game: Two Knights Defense |  Steinitz ...
#
#        opening_ply
# 950              6
# 1794             7
# 1830             3
# 2554             4
# 2556             5
# ...            ...
# 20013            6
# 20014           17
# 20015            8
# 20016            2
# 20017           17
#
# [429 rows x 16 columns]

# %%
# checking that they are true duplicates:
for id in duplicate_games['id']:
    print(games_df[games_df['id']==id])
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 120    XRuQPSzH   True  1.503580e+12  1.503580e+12     50         resign
# 950    XRuQPSzH   True  1.503580e+12  1.503580e+12     50         resign
# 12412  XRuQPSzH   True  1.503584e+12  1.503584e+12     50         resign
# 13729  XRuQPSzH   True  1.503584e+12  1.503584e+12     50         resign
# 14403  XRuQPSzH   True  1.503584e+12  1.503584e+12     50         resign
#
#       winner increment_code     white_id  white_rating black_id  black_rating  \
# 120    black           10+0  chess-brahs          2036     cdvh          1706
# 950    black           10+0  chess-brahs          2036     cdvh          1706
# 12412  black           10+0  chess-brahs          2036     cdvh          1706
# 13729  black           10+0  chess-brahs          2036     cdvh          1706
# 14403  black           10+0  chess-brahs          2036     cdvh          1706
#
#                                                    moves opening_eco  \
# 120    Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...         A08
# 950    Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...         A08
# 12412  Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...         A08
# 13729  Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...         A08
# 14403  Nf3 d5 g3 c5 Bg2 Nc6 d3 Nf6 O-O e5 Nc3 d4 Ne4 ...         A08
#
#                                  opening_name  opening_ply
# 120    King's Indian Attack: French Variation            6
# 950    King's Indian Attack: French Variation            6
# 12412  King's Indian Attack: French Variation            6
# 13729  King's Indian Attack: French Variation            6
# 14403  King's Indian Attack: French Variation            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 1443   x1Svcl0P   True  1.499820e+12  1.499830e+12     59           mate
# 1794   x1Svcl0P   True  1.499820e+12  1.499830e+12     59           mate
# 15009  x1Svcl0P   True  1.499825e+12  1.499826e+12     59           mate
#
#       winner increment_code         white_id  white_rating         black_id  \
# 1443   white           10+0  kachess10204542          1171  quantummequanic
# 1794   white           10+0  kachess10204542          1171  quantummequanic
# 15009  white           10+0  kachess10204542          1171  quantummequanic
#
#        black_rating                                              moves  \
# 1443           1432  c4 e5 Nc3 Nf6 Nf3 Nc6 g3 d5 cxd5 Nxd5 Bg2 Be6 ...
# 1794           1432  c4 e5 Nc3 Nf6 Nf3 Nc6 g3 d5 cxd5 Nxd5 Bg2 Be6 ...
# 15009          1432  c4 e5 Nc3 Nf6 Nf3 Nc6 g3 d5 cxd5 Nxd5 Bg2 Be6 ...
#
#       opening_eco                                       opening_name  \
# 1443          A29  English Opening: King's English Variation |  F...
# 1794          A29  English Opening: King's English Variation |  F...
# 15009         A29  English Opening: King's English Variation |  F...
#
#        opening_ply
# 1443             7
# 1794             7
# 15009            7
#              id  rated    created_at  last_move_at  turns victory_status  \
# 1795   wgIHzqDo   True  1.499710e+12  1.499710e+12    113           mate
# 1830   wgIHzqDo   True  1.499710e+12  1.499710e+12    113           mate
# 15010  wgIHzqDo   True  1.499712e+12  1.499714e+12    113           mate
#
#       winner increment_code         white_id  white_rating      black_id  \
# 1795   white           10+0  quantummequanic          1403  barrow-wight
# 1830   white           10+0  quantummequanic          1403  barrow-wight
# 15010  white           10+0  quantummequanic          1403  barrow-wight
#
#        black_rating                                              moves  \
# 1795           1364  e4 e6 e5 Bc5 d4 Be7 c3 Nh6 Bxh6 gxh6 Qd2 Bg5 f...
# 1830           1364  e4 e6 e5 Bc5 d4 Be7 c3 Nh6 Bxh6 gxh6 Qd2 Bg5 f...
# 15010          1364  e4 e6 e5 Bc5 d4 Be7 c3 Nh6 Bxh6 gxh6 Qd2 Bg5 f...
#
#       opening_eco                     opening_name  opening_ply
# 1795          C00  French Defense: Steinitz Attack            3
# 1830          C00  French Defense: Steinitz Attack            3
# 15010         C00  French Defense: Steinitz Attack            3
#             id  rated    created_at  last_move_at  turns victory_status  \
# 2539  JrFxlGZo  False  1.489330e+12  1.489330e+12     78           mate
# 2554  JrFxlGZo  False  1.489330e+12  1.489330e+12     78           mate
#
#      winner increment_code white_id  white_rating    black_id  black_rating  \
# 2539  black           15+0  sp37578          1309  penguin100          1393
# 2554  black           15+0  sp37578          1309  penguin100          1393
#
#                                                   moves opening_eco  \
# 2539  e4 d5 exd5 Qxd5 Nc3 Qe6+ Qe2 Qc6 d3 Bf5 Qf3 Be...         B01
# 2554  e4 d5 exd5 Qxd5 Nc3 Qe6+ Qe2 Qc6 d3 Bf5 Qf3 Be...         B01
#
#                                        opening_name  opening_ply
# 2539  Scandinavian Defense: Mieses-Kotroc Variation            4
# 2554  Scandinavian Defense: Mieses-Kotroc Variation            4
#             id  rated    created_at  last_move_at  turns victory_status  \
# 2540  ezKACesj  False  1.488840e+12  1.488840e+12     51           mate
# 2556  ezKACesj  False  1.488840e+12  1.488840e+12     51           mate
#
#      winner increment_code    white_id  white_rating black_id  black_rating  \
# 2540  white           15+0  penguin100          1393  sp37578          1309
# 2556  white           15+0  penguin100          1393  sp37578          1309
#
#                                                   moves opening_eco  \
# 2540  d4 d5 e3 Nf6 Nf3 b6 Nc3 Bb7 Bb5+ Nc6 Ne5 e6 O-...         D04
# 2556  d4 d5 e3 Nf6 Nf3 b6 Nc3 Bb7 Bb5+ Nc6 Ne5 e6 O-...         D04
#
#                          opening_name  opening_ply
# 2540  Queen's Pawn Game: Colle System            5
# 2556  Queen's Pawn Game: Colle System            5
#             id  rated    created_at  last_move_at  turns victory_status  \
# 2542  UVUUmRSQ  False  1.488730e+12  1.488730e+12     56           mate
# 2558  UVUUmRSQ  False  1.488730e+12  1.488730e+12     56           mate
#
#      winner increment_code    white_id  white_rating black_id  black_rating  \
# 2542  black           15+0  penguin100          1393  sp37578          1309
# 2558  black           15+0  penguin100          1393  sp37578          1309
#
#                                                   moves opening_eco  \
# 2542  d4 d5 e3 Nf6 Bb5+ Nc6 Bd3 e6 c3 Bd6 Nf3 Bd7 O-...         D00
# 2558  d4 d5 e3 Nf6 Bb5+ Nc6 Bd3 e6 c3 Bd6 Nf3 Bd7 O-...         D00
#
#               opening_name  opening_ply
# 2542  Queen's Pawn Game #3            4
# 2558  Queen's Pawn Game #3            4
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1978  de8kkad4   True  1.489010e+12  1.489010e+12      2         resign
# 2699  de8kkad4   True  1.489010e+12  1.489010e+12      2         resign
#
#      winner increment_code       white_id  white_rating         black_id  \
# 1978  white            9+1  sneaky_bugger          1765  tactical_bishop
# 2699  white            9+1  sneaky_bugger          1765  tactical_bishop
#
#       black_rating  moves opening_eco         opening_name  opening_ply
# 1978          1234  b3 g6         A01  Nimzo-Larsen Attack            1
# 2699          1234  b3 g6         A01  Nimzo-Larsen Attack            1
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1979  yvqpdUQE   True  1.489010e+12  1.489010e+12     26           mate
# 2700  yvqpdUQE   True  1.489010e+12  1.489010e+12     26           mate
#
#      winner increment_code         white_id  white_rating       black_id  \
# 1979  black            9+1  tactical_bishop          1246  sneaky_bugger
# 2700  black            9+1  tactical_bishop          1246  sneaky_bugger
#
#       black_rating                                              moves  \
# 1979          1753  d4 e5 dxe5 Bb4+ Nd2 Qg5 b3 Nc6 Bb2 Nh6 g3 O-O ...
# 2700          1753  d4 e5 dxe5 Bb4+ Nd2 Qg5 b3 Nc6 Bb2 Nh6 g3 O-O ...
#
#      opening_eco    opening_name  opening_ply
# 1979         A40  Englund Gambit            2
# 2700         A40  Englund Gambit            2
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1980  dQCCZY4f   True  1.489010e+12  1.489010e+12     12         resign
# 2701  dQCCZY4f   True  1.489010e+12  1.489010e+12     12         resign
#
#      winner increment_code       white_id  white_rating         black_id  \
# 1980  white            9+1  sneaky_bugger          1739  tactical_bishop
# 2701  white            9+1  sneaky_bugger          1739  tactical_bishop
#
#       black_rating                                      moves opening_eco  \
# 1980          1260  g3 d5 Bg2 e5 Nf3 e4 Nd4 Bc5 c3 Na6 e3 Nf6         A00
# 2701          1260  g3 d5 Bg2 e5 Nf3 e4 Nd4 Bc5 c3 Na6 e3 Nf6         A00
#
#            opening_name  opening_ply
# 1980  Hungarian Opening            1
# 2701  Hungarian Opening            1
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1981  8zGwL053   True  1.489010e+12  1.489010e+12     14         resign
# 2702  8zGwL053   True  1.489010e+12  1.489010e+12     14         resign
#
#      winner increment_code         white_id  white_rating       black_id  \
# 1981  black            9+1  tactical_bishop          1279  sneaky_bugger
# 2702  black            9+1  tactical_bishop          1279  sneaky_bugger
#
#       black_rating                                              moves  \
# 1981          1720  b3 g6 Bb2 Nf6 Bxf6 exf6 Nc3 Bg7 g3 f5 Bg2 Bxc3...
# 2702          1720  b3 g6 Bb2 Nf6 Bxf6 exf6 Nc3 Bg7 g3 f5 Bg2 Bxc3...
#
#      opening_eco         opening_name  opening_ply
# 1981         A01  Nimzo-Larsen Attack            1
# 2702         A01  Nimzo-Larsen Attack            1
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1982  2QYrX7bz   True  1.489010e+12  1.489010e+12     73           mate
# 2703  2QYrX7bz   True  1.489010e+12  1.489010e+12     73           mate
#
#      winner increment_code       white_id  white_rating         black_id  \
# 1982  white            9+1  sneaky_bugger          1694  tactical_bishop
# 2703  white            9+1  sneaky_bugger          1694  tactical_bishop
#
#       black_rating                                              moves  \
# 1982          1305  Nf3 e6 g3 Bd6 Bg2 Nf6 O-O O-O d4 e5 dxe5 Bc5 e...
# 2703          1305  Nf3 e6 g3 Bd6 Bg2 Nf6 O-O O-O d4 e5 dxe5 Bc5 e...
#
#      opening_eco                                  opening_name  opening_ply
# 1982         A04  Zukertort Opening: Queen's Gambit Invitation            2
# 2703         A04  Zukertort Opening: Queen's Gambit Invitation            2
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1983  QGXLgc6L   True  1.489010e+12  1.489010e+12      3         resign
# 2704  QGXLgc6L   True  1.489010e+12  1.489010e+12      3         resign
#
#      winner increment_code       white_id  white_rating         black_id  \
# 1983  white            9+1  sneaky_bugger          1654  tactical_bishop
# 2704  white            9+1  sneaky_bugger          1654  tactical_bishop
#
#       black_rating      moves opening_eco         opening_name  opening_ply
# 1983          1345  b3 f6 Bb2         A01  Nimzo-Larsen Attack            1
# 2704          1345  b3 f6 Bb2         A01  Nimzo-Larsen Attack            1
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1984  J62F4oVs   True  1.489010e+12  1.489010e+12      6         resign
# 2705  J62F4oVs   True  1.489010e+12  1.489010e+12      6         resign
#
#      winner increment_code         white_id  white_rating       black_id  \
# 1984  black            9+1  tactical_bishop          1423  sneaky_bugger
# 2705  black            9+1  tactical_bishop          1423  sneaky_bugger
#
#       black_rating                  moves opening_eco  \
# 1984          1576  d4 e6 e4 Qh4 Bg5 Qxg5         C00
# 2705          1576  d4 e6 e4 Qh4 Bg5 Qxg5         C00
#
#                           opening_name  opening_ply
# 1984  French Defense: Normal Variation            3
# 2705  French Defense: Normal Variation            3
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1985  M1zbHN7r   True  1.489000e+12  1.489010e+12     26           draw
# 2706  M1zbHN7r   True  1.489000e+12  1.489010e+12     26           draw
#
#      winner increment_code       white_id  white_rating         black_id  \
# 1985   draw            9+1  sneaky_bugger          1662  tactical_bishop
# 2706   draw            9+1  sneaky_bugger          1662  tactical_bishop
#
#       black_rating                                              moves  \
# 1985          1337  d4 c5 dxc5 f5 Bf4 e6 Bd6 Bxd6 cxd6 Nf6 Qd4 g6 ...
# 2706          1337  d4 c5 dxc5 f5 Bf4 e6 Bd6 Bxd6 cxd6 Nf6 Qd4 g6 ...
#
#      opening_eco                            opening_name  opening_ply
# 1985         A43  Benoni Defense: Benoni Gambit Accepted            3
# 2706         A43  Benoni Defense: Benoni Gambit Accepted            3
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1986  i4dYtT5Z   True  1.489000e+12  1.489000e+12      3         resign
# 2707  i4dYtT5Z   True  1.489000e+12  1.489000e+12      3         resign
#
#      winner increment_code         white_id  white_rating       black_id  \
# 1986  black           10+0  tactical_bishop          1500  sneaky_bugger
# 2707  black           10+0  tactical_bishop          1500  sneaky_bugger
#
#       black_rating      moves opening_eco     opening_name  opening_ply
# 1986          1500  d4 e6 Bf4         A40  Horwitz Defense            2
# 2707          1500  d4 e6 Bf4         A40  Horwitz Defense            2
#             id  rated    created_at  last_move_at  turns victory_status  \
# 4241  vwkSIpZ0   True  1.474470e+12  1.474470e+12     75           mate
# 4271  vwkSIpZ0   True  1.474470e+12  1.474470e+12     75           mate
#
#      winner increment_code       white_id  white_rating black_id  \
# 4241  white            7+2  kasparovd0311          1473  chees29
# 4271  white            7+2  kasparovd0311          1473  chees29
#
#       black_rating                                              moves  \
# 4241          1221  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Nf6 O-O Be7 Re1 O-O B...
# 4271          1221  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Nf6 O-O Be7 Re1 O-O B...
#
#      opening_eco                  opening_name  opening_ply
# 4241         C84  Ruy Lopez: Closed Variations           10
# 4271         C84  Ruy Lopez: Closed Variations           10
#             id  rated    created_at  last_move_at  turns victory_status  \
# 6081  RhLRiClg   True  1.456110e+12  1.456110e+12     11           draw
# 6452  RhLRiClg   True  1.456110e+12  1.456110e+12     11           draw
#
#      winner increment_code     white_id  white_rating black_id  black_rating  \
# 6081   draw            5+8  awesomegurl          1500    golal          1210
# 6452   draw            5+8  awesomegurl          1500    golal          1210
#
#                                         moves opening_eco  \
# 6081  b3 a5 c3 Ra6 c4 Rc6 e3 Rxc4 bxc4 a4 Na3         A01
# 6452  b3 a5 c3 Ra6 c4 Rc6 e3 Rxc4 bxc4 a4 Na3         A01
#
#              opening_name  opening_ply
# 6081  Nimzo-Larsen Attack            1
# 6452  Nimzo-Larsen Attack            1
#             id  rated    created_at  last_move_at  turns victory_status  \
# 9678  HvrORfUp   True  1.415628e+12  1.415629e+12    102           draw
# 9916  HvrORfUp   True  1.415628e+12  1.415629e+12    102           draw
#
#      winner increment_code       white_id  white_rating        black_id  \
# 9678   draw        180+180  amazingdragon          1430  amazingfoxtrot
# 9916   draw        180+180  amazingdragon          1430  amazingfoxtrot
#
#       black_rating                                              moves  \
# 9678          1667  f4 e5 Nf3 exf4 c4 Bb4 Kf2 Bc5+ Ke1 Bf2+ Kxf2 h...
# 9916          1667  f4 e5 Nf3 exf4 c4 Bb4 Kf2 Bc5+ Ke1 Bf2+ Kxf2 h...
#
#      opening_eco                 opening_name  opening_ply
# 9678         A02  Bird Opening: From's Gambit            2
# 9916         A02  Bird Opening: From's Gambit            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10503  6tjettIT   True  1.446190e+12  1.446191e+12     58      outoftime
# 11212  6tjettIT   True  1.446190e+12  1.446191e+12     58      outoftime
#
#       winner increment_code white_id  white_rating      black_id  \
# 10503  black           10+0   tori92          2096  reza-kondazi
# 11212  black           10+0   tori92          2096  reza-kondazi
#
#        black_rating                                              moves  \
# 10503          1901  e4 c6 d4 d5 exd5 cxd5 Nf3 Nc6 c3 Bg4 Be2 e6 Bf...
# 11212          1901  e4 c6 d4 d5 exd5 cxd5 Nf3 Nc6 c3 Bg4 Be2 e6 Bf...
#
#       opening_eco                           opening_name  opening_ply
# 10503         B13  Caro-Kann Defense: Exchange Variation            5
# 11212         B13  Caro-Kann Defense: Exchange Variation            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10504  glk9SiIG   True  1.446189e+12  1.446190e+12     68         resign
# 11213  glk9SiIG   True  1.446189e+12  1.446190e+12     68         resign
#
#       winner increment_code      white_id  white_rating black_id  \
# 10504  black           10+0  reza-kondazi          1920   tori92
# 11213  black           10+0  reza-kondazi          1920   tori92
#
#        black_rating                                              moves  \
# 10504          2087  d4 d5 Nf3 Nf6 g3 e6 Bg2 c5 O-O Nc6 c3 Bd7 Bg5 ...
# 11213          2087  d4 d5 Nf3 Nf6 g3 e6 Bg2 c5 O-O Nc6 c3 Bd7 Bg5 ...
#
#       opening_eco                                       opening_name  \
# 10504         D02  Queen's Pawn Game: Symmetrical Variation |  Ps...
# 11213         D02  Queen's Pawn Game: Symmetrical Variation |  Ps...
#
#        opening_ply
# 10504            5
# 11213            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10505  hrnqkGeJ   True  1.446172e+12  1.446173e+12     54           mate
# 11214  hrnqkGeJ   True  1.446172e+12  1.446173e+12     54           mate
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10505  black            5+8  ashilov          2004   tori92          2073
# 11214  black            5+8  ashilov          2004   tori92          2073
#
#                                                    moves opening_eco  \
# 10505  e4 Nf6 Nc3 e5 Nf3 Nc6 d4 exd4 Nxd4 Bb4 Nxc6 bx...         C47
# 11214  e4 Nf6 Nc3 e5 Nf3 Nc6 d4 exd4 Nxd4 Bb4 Nxc6 bx...         C47
#
#                                        opening_name  opening_ply
# 10505  Four Knights Game: Scotch Variation Accepted            8
# 11214  Four Knights Game: Scotch Variation Accepted            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10506  3CB6Onyb   True  1.446093e+12  1.446094e+12    113           mate
# 11215  3CB6Onyb   True  1.446093e+12  1.446094e+12    113           mate
#
#       winner increment_code white_id  white_rating         black_id  \
# 10506  white           10+0   tori92          2084  sunsettosunrise
# 11215  white           10+0   tori92          2084  sunsettosunrise
#
#        black_rating                                              moves  \
# 10506          2066  e4 c5 Nf3 d6 d4 cxd4 Nxd4 Nf6 Nc3 g6 Bb5+ Nbd7...
# 11215          2066  e4 c5 Nf3 d6 d4 cxd4 Nxd4 Nf6 Nc3 g6 Bb5+ Nbd7...
#
#       opening_eco                        opening_name  opening_ply
# 10506         B70  Sicilian Defense: Dragon Variation           10
# 11215         B70  Sicilian Defense: Dragon Variation           10
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10507  lKTxTrKz   True  1.446091e+12  1.446092e+12    149         resign
# 11216  lKTxTrKz   True  1.446091e+12  1.446092e+12    149         resign
#
#       winner increment_code white_id  white_rating              black_id  \
# 10507  white            5+5   tori92          2074  belgranocbafilialita
# 11216  white            5+5   tori92          2074  belgranocbafilialita
#
#        black_rating                                              moves  \
# 10507          1908  e4 e5 Nf3 d6 Nc3 Nf6 Bc4 Be7 h3 O-O d4 exd4 Nx...
# 11216          1908  e4 e5 Nf3 d6 Nc3 Nf6 Bc4 Be7 h3 O-O d4 exd4 Nx...
#
#       opening_eco         opening_name  opening_ply
# 10507         C41  Philidor Defense #2            4
# 11216         C41  Philidor Defense #2            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10508  KcmaRSxt   True  1.446086e+12  1.446087e+12     64           mate
# 11217  KcmaRSxt   True  1.446086e+12  1.446087e+12     64           mate
#
#       winner increment_code    white_id  white_rating black_id  black_rating  \
# 10508  black            5+5  huntermind          1788   tori92          2067
# 11217  black            5+5  huntermind          1788   tori92          2067
#
#                                                    moves opening_eco  \
# 10508  e4 Nf6 e5 Nd5 c4 Nb6 Nf3 d6 exd6 cxd6 d4 g6 Be...         B02
# 11217  e4 Nf6 e5 Nd5 c4 Nb6 Nf3 d6 exd6 cxd6 d4 g6 Be...         B02
#
#                             opening_name  opening_ply
# 10508  Alekhine Defense: Two Pawn Attack            5
# 11217  Alekhine Defense: Two Pawn Attack            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10509  6aDFIWBG   True  1.446085e+12  1.446086e+12     59         resign
# 11218  6aDFIWBG   True  1.446085e+12  1.446086e+12     59         resign
#
#       winner increment_code white_id  white_rating    black_id  black_rating  \
# 10509  white            5+5   tori92          2060  huntermind          1792
# 11218  white            5+5   tori92          2060  huntermind          1792
#
#                                                    moves opening_eco  \
# 10509  e4 c6 d4 d5 e5 Bf5 Nf3 e6 c4 Ne7 c5 Ng6 Nc3 Be...         B12
# 11218  e4 c6 d4 d5 e5 Bf5 Nf3 e6 c4 Ne7 c5 Ng6 Nc3 Be...         B12
#
#                                             opening_name  opening_ply
# 10509  Caro-Kann Defense: Advance Variation |  Short ...            7
# 11218  Caro-Kann Defense: Advance Variation |  Short ...            7
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10510  JwFWnETl   True  1.446007e+12  1.446008e+12     74         resign
# 11219  JwFWnETl   True  1.446007e+12  1.446008e+12     74         resign
#
#       winner increment_code  white_id  white_rating black_id  black_rating  \
# 10510  black           2+10  aalmeida          1819   tori92          2052
# 11219  black           2+10  aalmeida          1819   tori92          2052
#
#                                                    moves opening_eco  \
# 10510  e4 Nf6 e5 Nd5 d4 d6 exd6 cxd6 Nf3 Nc6 Be2 g6 O...         B03
# 11219  e4 Nf6 e5 Nd5 d4 d6 exd6 cxd6 Nf3 Nc6 Be2 g6 O...         B03
#
#            opening_name  opening_ply
# 10510  Alekhine Defense            6
# 11219  Alekhine Defense            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10511  8dRrl55X   True  1.446007e+12  1.446007e+12     47         resign
# 11220  8dRrl55X   True  1.446007e+12  1.446007e+12     47         resign
#
#       winner increment_code white_id  white_rating  black_id  black_rating  \
# 10511  white           10+0   tori92          2047  artsk757          1710
# 11220  white           10+0   tori92          2047  artsk757          1710
#
#                                                    moves opening_eco  \
# 10511  e4 Nf6 e5 Nd5 d4 d6 Nf3 Bg4 Bc4 e6 O-O Nb6 Bb5...         B05
# 11220  e4 Nf6 e5 Nd5 d4 d6 Nf3 Bg4 Bc4 e6 O-O Nb6 Bb5...         B05
#
#                                           opening_name  opening_ply
# 10511  Alekhine Defense: Modern Variation |  Main Line            8
# 11220  Alekhine Defense: Modern Variation |  Main Line            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10512  wFstU6H4   True  1.396510e+12  1.396511e+12    117           mate
# 11221  wFstU6H4   True  1.396510e+12  1.396511e+12    117           mate
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10512  white           10+5  vit2014          2136   tori92          2062
# 11221  white           10+5  vit2014          2136   tori92          2062
#
#                                                    moves opening_eco  \
# 10512  d4 d5 Nf3 Nf6 c4 Nc6 e3 Bg4 Qb3 Bxf3 gxf3 Na5 ...         D02
# 11221  d4 d5 Nf3 Nf6 c4 Nc6 e3 Bg4 Qb3 Bxf3 gxf3 Na5 ...         D02
#
#                                    opening_name  opening_ply
# 10512  Queen's Pawn Game: Symmetrical Variation            4
# 11221  Queen's Pawn Game: Symmetrical Variation            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10513  MBiEb6b1   True  1.396500e+12  1.396501e+12     30      outoftime
# 11222  MBiEb6b1   True  1.396500e+12  1.396501e+12     30      outoftime
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10513  black            5+7   tori92          2081  marikov          2096
# 11222  black            5+7   tori92          2081  marikov          2096
#
#                                                    moves opening_eco  \
# 10513  e4 c5 Nf3 Nc6 Bc4 d6 Nc3 Bg4 h3 Bh5 g4 Bg6 h4 ...         B30
# 11222  e4 c5 Nf3 Nc6 Bc4 d6 Nc3 Bg4 h3 Bh5 g4 Bg6 h4 ...         B30
#
#                          opening_name  opening_ply
# 10513  Sicilian Defense: Old Sicilian            4
# 11222  Sicilian Defense: Old Sicilian            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10514  I68gWMT3   True  1.396496e+12  1.396498e+12     59      outoftime
# 11223  I68gWMT3   True  1.396496e+12  1.396498e+12     59      outoftime
#
#       winner increment_code white_id  white_rating      black_id  \
# 10514  white           25+0   tori92          2063  danlokgarzon
# 11223  white           25+0   tori92          2063  danlokgarzon
#
#        black_rating                                              moves  \
# 10514          2027  e4 g6 d4 Bg7 Nf3 c6 c4 d6 Nc3 f5 Bf4 Nd7 Bd3 e...
# 11223          2027  e4 g6 d4 Bg7 Nf3 c6 c4 d6 Nc3 f5 Bf4 Nd7 Bd3 e...
#
#       opening_eco               opening_name  opening_ply
# 10514         B06  Robatsch (Modern) Defense            4
# 11223         B06  Robatsch (Modern) Defense            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10515  jEV6APzw   True  1.396407e+12  1.396409e+12    117         resign
# 11224  jEV6APzw   True  1.396407e+12  1.396409e+12    117         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10515  white           5+21   tori92          2048  2700172          1924
# 11224  white           5+21   tori92          2048  2700172          1924
#
#                                                    moves opening_eco  \
# 10515  e4 e5 Nf3 Nc6 c3 Nf6 d4 exd4 e5 Ng8 cxd4 Bb4+ ...         C44
# 11224  e4 e5 Nf3 Nc6 c3 Nf6 d4 exd4 e5 Ng8 cxd4 Bb4+ ...         C44
#
#                                    opening_name  opening_ply
# 10515  Ponziani Opening: Jaenisch Counterattack            6
# 11224  Ponziani Opening: Jaenisch Counterattack            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10516  myf3zxVd  False  1.396372e+12  1.396373e+12     31         resign
# 11225  myf3zxVd  False  1.396372e+12  1.396373e+12     31         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10516  white           19+4   tori92          1804  babacom          1997
# 11225  white           19+4   tori92          1804  babacom          1997
#
#                                                    moves opening_eco  \
# 10516  e4 e5 Nf3 Nf6 Nc3 Nc6 Bc4 Nxe4 Bxf7+ Kxf7 Nxe4...         C47
# 11225  e4 e5 Nf3 Nf6 Nc3 Nc6 Bc4 Nxe4 Bxf7+ Kxf7 Nxe4...         C47
#
#                                             opening_name  opening_ply
# 10516  Four Knights Game: Italian Variation |  Noa Ga...            9
# 11225  Four Knights Game: Italian Variation |  Noa Ga...            9
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10517  qtO43RJL   True  1.396332e+12  1.396333e+12     55         resign
# 11226  qtO43RJL   True  1.396332e+12  1.396333e+12     55         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10517  white           10+0   nesa10          2051   tori92          2072
# 11226  white           10+0   nesa10          2051   tori92          2072
#
#                                                    moves opening_eco  \
# 10517  e4 e5 Nf3 Nc6 Bb5 a6 Bc4 Bc5 d3 Nf6 h3 O-O Bg5...         C70
# 11226  e4 e5 Nf3 Nc6 Bb5 a6 Bc4 Bc5 d3 Nf6 h3 O-O Bg5...         C70
#
#       opening_name  opening_ply
# 10517    Ruy Lopez            6
# 11226    Ruy Lopez            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10518  zI4GBeD7   True  1.396330e+12  1.396330e+12     67         resign
# 11227  zI4GBeD7   True  1.396330e+12  1.396330e+12     67         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10518  white           5+21   tori92          2057  2700172          1923
# 11227  white           5+21   tori92          2057  2700172          1923
#
#                                                    moves opening_eco  \
# 10518  e4 e5 Nf3 Nc6 c3 Nf6 d4 exd4 e5 Ng8 cxd4 Bb4+ ...         C44
# 11227  e4 e5 Nf3 Nc6 c3 Nf6 d4 exd4 e5 Ng8 cxd4 Bb4+ ...         C44
#
#                                    opening_name  opening_ply
# 10518  Ponziani Opening: Jaenisch Counterattack            6
# 11227  Ponziani Opening: Jaenisch Counterattack            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10519  KEywC6kR   True  1.396321e+12  1.396322e+12     82         resign
# 11228  KEywC6kR   True  1.396321e+12  1.396322e+12     82         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10519  black           5+21  2700172          1922   tori92          2040
# 11228  black           5+21  2700172          1922   tori92          2040
#
#                                                    moves opening_eco  \
# 10519  e4 e5 Bc4 Nc6 Nc3 Bc5 d3 Nf6 Nf3 d6 h3 O-O O-O...         C50
# 11228  e4 e5 Bc4 Nc6 Nc3 Bc5 d3 Nf6 Nf3 d6 h3 O-O O-O...         C50
#
#                                             opening_name  opening_ply
# 10519  Italian Game: Giuoco Pianissimo |  Italian Fou...            9
# 11228  Italian Game: Giuoco Pianissimo |  Italian Fou...            9
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10520  dcGMkHUE   True  1.396284e+12  1.396287e+12    144           draw
# 11229  dcGMkHUE   True  1.396284e+12  1.396287e+12    144           draw
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10520   draw           30+1     nolp          2063   tori92          2038
# 11229   draw           30+1     nolp          2063   tori92          2038
#
#                                                    moves opening_eco  \
# 10520  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Bc5 O-O b5 Bb3 Nf6 Nx...         C70
# 11229  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Bc5 O-O b5 Bb3 Nf6 Nx...         C70
#
#                                             opening_name  opening_ply
# 10520  Ruy Lopez: Morphy Defense |  Classical Defense...            8
# 11229  Ruy Lopez: Morphy Defense |  Classical Defense...            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10521  uc2tMYfY   True  1.396283e+12  1.396284e+12     53         resign
# 11230  uc2tMYfY   True  1.396283e+12  1.396284e+12     53         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10521  white           30+1   tori92          2003     nolp          2078
# 11230  white           30+1   tori92          2003     nolp          2078
#
#                                                    moves opening_eco  \
# 10521  e4 e5 Nf3 Nc6 c3 d5 Qa4 Qd6 d4 Bd7 Bb5 dxe4 Nx...         C44
# 11230  e4 e5 Nf3 Nc6 c3 d5 Qa4 Qd6 d4 Bd7 Bb5 dxe4 Nx...         C44
#
#            opening_name  opening_ply
# 10521  Ponziani Opening            5
# 11230  Ponziani Opening            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10522  bx2fK6DQ   True  1.396283e+12  1.396283e+12     52         resign
# 11231  bx2fK6DQ   True  1.396283e+12  1.396283e+12     52         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10522  white           5+10   tori92          1996   astass          1618
# 11231  white           5+10   tori92          1996   astass          1618
#
#                                                    moves opening_eco  \
# 10522  e4 e5 Nf3 Nc6 c3 a6 d4 Bd6 Bd3 h6 O-O Nf6 dxe5...         C44
# 11231  e4 e5 Nf3 Nc6 c3 a6 d4 Bd6 Bd3 h6 O-O Nf6 dxe5...         C44
#
#            opening_name  opening_ply
# 10522  Ponziani Opening            5
# 11231  Ponziani Opening            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10523  fPjHFTNL   True  1.396279e+12  1.396280e+12    138           draw
# 11232  fPjHFTNL   True  1.396279e+12  1.396280e+12    138           draw
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10523   draw            6+8   jafari          1804   tori92          2013
# 11232   draw            6+8   jafari          1804   tori92          2013
#
#                                                    moves opening_eco  \
# 10523  d4 d5 e3 Nf6 c4 Nc6 Nc3 e6 Nf3 Bb4 a3 Bxc3+ bx...         D00
# 11232  d4 d5 e3 Nf6 c4 Nc6 Nc3 e6 Nf3 Bb4 a3 Bxc3+ bx...         D00
#
#                opening_name  opening_ply
# 10523  Queen's Pawn Game #3            4
# 11232  Queen's Pawn Game #3            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10524  TAJtb4qg   True  1.396275e+12  1.396275e+12     46         resign
# 11233  TAJtb4qg   True  1.396275e+12  1.396275e+12     46         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 10524  black           10+4    pikur          1834   tori92          1994
# 11233  black           10+4    pikur          1834   tori92          1994
#
#                                                    moves opening_eco  \
# 10524  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Bc5 O-O d6 Bxc6+ bxc6...         C70
# 11233  e4 e5 Nf3 Nc6 Bb5 a6 Ba4 Bc5 O-O d6 Bxc6+ bxc6...         C70
#
#                                             opening_name  opening_ply
# 10524  Ruy Lopez: Morphy Defense |  Classical Defense...            8
# 11233  Ruy Lopez: Morphy Defense |  Classical Defense...            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10525  pzqKLpeT   True  1.396272e+12  1.396273e+12     85         resign
# 11234  pzqKLpeT   True  1.396272e+12  1.396273e+12     85         resign
#
#       winner increment_code   white_id  white_rating black_id  black_rating  \
# 10525  black            9+0  diogen613          1867   tori92          1968
# 11234  black            9+0  diogen613          1867   tori92          1968
#
#                                                    moves opening_eco  \
# 10525  e4 e5 Bc4 Nc6 Nc3 Bc5 Nf3 Nf6 d3 d6 Bg5 h6 Bh4...         C50
# 11234  e4 e5 Bc4 Nc6 Nc3 Bc5 Nf3 Nf6 d3 d6 Bg5 h6 Bh4...         C50
#
#                                             opening_name  opening_ply
# 10525  Italian Game: Giuoco Pianissimo |  Canal Varia...           11
# 11234  Italian Game: Giuoco Pianissimo |  Canal Varia...           11
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10526  UUqJfPGz   True  1.397928e+12  1.397929e+12     43         resign
# 11235  UUqJfPGz   True  1.397928e+12  1.397929e+12     43         resign
#
#       winner increment_code            white_id  white_rating black_id  \
# 10526  white          15+10  vladimir-kramnik-1          1653   elena1
# 11235  white          15+10  vladimir-kramnik-1          1653   elena1
#
#        black_rating                                              moves  \
# 10526          1711  e4 g6 d4 Bg7 Nf3 c6 Be3 b5 Nc3 b4 Ne2 Qa5 c3 b...
# 11235          1711  e4 g6 d4 Bg7 Nf3 c6 Be3 b5 Nc3 b4 Ne2 Qa5 c3 b...
#
#       opening_eco               opening_name  opening_ply
# 10526         B06  Robatsch (Modern) Defense            4
# 11235         B06  Robatsch (Modern) Defense            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10527  WKCIzgls   True  1.397927e+12  1.397928e+12     85         resign
# 11236  WKCIzgls   True  1.397927e+12  1.397928e+12     85         resign
#
#       winner increment_code            white_id  white_rating black_id  \
# 10527  black           10+5  vladimir-kramnik-1          1663      gid
# 11236  black           10+5  vladimir-kramnik-1          1663      gid
#
#        black_rating                                              moves  \
# 10527          1706  e4 e5 Nf3 Nc6 Bb5 d6 d4 exd4 Nxd4 Bd7 Bc4 Ne5 ...
# 11236          1706  e4 e5 Nf3 Nc6 Bb5 d6 d4 exd4 Nxd4 Bd7 Bc4 Ne5 ...
#
#       opening_eco                 opening_name  opening_ply
# 10527         C62  Ruy Lopez: Steinitz Defense            6
# 11236         C62  Ruy Lopez: Steinitz Defense            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10528  3tX9qTuT   True  1.397628e+12  1.397628e+12     49         resign
# 11237  3tX9qTuT   True  1.397628e+12  1.397628e+12     49         resign
#
#       winner increment_code white_id  white_rating            black_id  \
# 10528  white           15+5  iosif22          1692  vladimir-kramnik-1
# 11237  white           15+5  iosif22          1692  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10528          1674  e4 e6 Nf3 d5 exd5 exd5 d4 c5 c4 Nf6 Be2 Nc6 O-...
# 11237          1674  e4 e6 Nf3 d5 exd5 exd5 d4 c5 c4 Nf6 Be2 Nc6 O-...
#
#       opening_eco                      opening_name  opening_ply
# 10528         C00  French Defense: Knight Variation            3
# 11237         C00  French Defense: Knight Variation            3
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10529  We79CGAj   True  1.397564e+12  1.397565e+12     91           mate
# 11238  We79CGAj   True  1.397564e+12  1.397565e+12     91           mate
#
#       winner increment_code white_id  white_rating            black_id  \
# 10529  white           8+10    reabb          1709  vladimir-kramnik-1
# 11238  white           8+10    reabb          1709  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10529          1685  d4 d5 c4 c6 Nc3 e6 a3 Nf6 c5 Be7 Nf3 b6 b4 bxc...
# 11238          1685  d4 d5 c4 c6 Nc3 e6 a3 Nf6 c5 Be7 Nf3 b6 b4 bxc...
#
#       opening_eco                               opening_name  opening_ply
# 10529         D31  Semi-Slav Defense: Accelerated Move Order            6
# 11238         D31  Semi-Slav Defense: Accelerated Move Order            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10530  SitO3W0e   True  1.397543e+12  1.397544e+12     69           mate
# 11239  SitO3W0e   True  1.397543e+12  1.397544e+12     69           mate
#
#       winner increment_code white_id  white_rating            black_id  \
# 10530  white           15+0  ponchic          1631  vladimir-kramnik-1
# 11239  white           15+0  ponchic          1631  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10530          1698  e4 e6 f4 d5 e5 c5 Nf3 Nc6 Bb5 a6 Bxc6+ bxc6 O-...
# 11239          1698  e4 e6 f4 d5 e5 c5 Nf3 Nc6 Bb5 a6 Bxc6+ bxc6 O-...
#
#       opening_eco                              opening_name  opening_ply
# 10530         C00  French Defense: La Bourdonnais Variation            3
# 11239         C00  French Defense: La Bourdonnais Variation            3
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10531  M0yXzeAG   True  1.397539e+12  1.397540e+12     87         resign
# 11240  M0yXzeAG   True  1.397539e+12  1.397540e+12     87         resign
#
#       winner increment_code            white_id  white_rating black_id  \
# 10531  black           8+10  vladimir-kramnik-1          1708    dater
# 11240  black           8+10  vladimir-kramnik-1          1708    dater
#
#        black_rating                                              moves  \
# 10531          1772  d4 e6 c4 b6 Nf3 Nc6 Nc3 Bb4 a3 Bxc3+ bxc3 Nge7...
# 11240          1772  d4 e6 c4 b6 Nf3 Nc6 Nc3 Bb4 a3 Bxc3+ bxc3 Nge7...
#
#       opening_eco     opening_name  opening_ply
# 10531         A40  English Defense            4
# 11240         A40  English Defense            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10532  FaBFS4A6   True  1.397499e+12  1.397500e+12    114         resign
# 11241  FaBFS4A6   True  1.397499e+12  1.397500e+12    114         resign
#
#       winner increment_code            white_id  white_rating        black_id  \
# 10532  black           8+10  vladimir-kramnik-1          1724  javadhajizadeh
# 11241  black           8+10  vladimir-kramnik-1          1724  javadhajizadeh
#
#        black_rating                                              moves  \
# 10532          1545  d4 d5 c4 dxc4 e4 g6 Bxc4 Bg7 Be3 Nc6 Bb5 Bd7 B...
# 11241          1545  d4 d5 c4 dxc4 e4 g6 Bxc4 Bg7 Be3 Nc6 Bb5 Bd7 B...
#
#       opening_eco                                 opening_name  opening_ply
# 10532         D20  Queen's Gambit Accepted: Saduleto Variation            5
# 11241         D20  Queen's Gambit Accepted: Saduleto Variation            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10533  BceRT6ia   True  1.397497e+12  1.397498e+12     56         resign
# 11242  BceRT6ia   True  1.397497e+12  1.397498e+12     56         resign
#
#       winner increment_code white_id  white_rating            black_id  \
# 10533  black           8+10  masa-90          1723  vladimir-kramnik-1
# 11242  black           8+10  masa-90          1723  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10533          1713  e4 e6 d3 d5 Nc3 c5 Nf3 d4 Ne2 Nc6 Ng3 Nf6 Be2 ...
# 11242          1713  e4 e6 d3 d5 Nc3 c5 Nf3 d4 Ne2 Nc6 Ng3 Nf6 Be2 ...
#
#       opening_eco                          opening_name  opening_ply
# 10533         C00  French Defense: King's Indian Attack            3
# 11242         C00  French Defense: King's Indian Attack            3
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10534  FWZXrmbd   True  1.397497e+12  1.397497e+12     34           mate
# 11243  FWZXrmbd   True  1.397497e+12  1.397497e+12     34           mate
#
#       winner increment_code      white_id  white_rating            black_id  \
# 10534  black           15+8  aleksey-2014          1642  vladimir-kramnik-1
# 11243  black           15+8  aleksey-2014          1642  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10534          1703  d4 d5 c3 e6 Nf3 c5 Ne5 Nc6 Nxc6 bxc6 e3 cxd4 e...
# 11243          1703  d4 d5 c3 e6 Nf3 c5 Ne5 Nc6 Nxc6 bxc6 e3 cxd4 e...
#
#       opening_eco       opening_name  opening_ply
# 10534         D00  Queen's Pawn Game            2
# 11243         D00  Queen's Pawn Game            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10535  Kos4NQdt   True  1.397496e+12  1.397497e+12     49           mate
# 11244  Kos4NQdt   True  1.397496e+12  1.397497e+12     49           mate
#
#       winner increment_code            white_id  white_rating black_id  \
# 10535  white           8+10  vladimir-kramnik-1          1689  pawnsya
# 11244  white           8+10  vladimir-kramnik-1          1689  pawnsya
#
#        black_rating                                              moves  \
# 10535          1770  d4 d5 c4 c6 Nf3 dxc4 e3 b5 Nc3 a6 g3 Nf6 a4 Bd...
# 11244          1770  d4 d5 c4 c6 Nf3 dxc4 e3 b5 Nc3 a6 g3 Nf6 a4 Bd...
#
#       opening_eco               opening_name  opening_ply
# 10535         D11  Slav Defense: Modern Line            5
# 11244         D11  Slav Defense: Modern Line            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10536  45JKnaVt   True  1.397476e+12  1.397477e+12     59         resign
# 11245  45JKnaVt   True  1.397476e+12  1.397477e+12     59         resign
#
#       winner increment_code   white_id  white_rating            black_id  \
# 10536  white          10+10  fedorstar          1763  vladimir-kramnik-1
# 11245  white          10+10  fedorstar          1763  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10536          1698  c4 e5 b3 Nf6 Bb2 Nc6 g3 d5 cxd5 Qxd5 Nf3 Bg4 B...
# 11245          1698  c4 e5 b3 Nf6 Bb2 Nc6 g3 d5 cxd5 Qxd5 Nf3 Bg4 B...
#
#       opening_eco                               opening_name  opening_ply
# 10536         A20  English Opening: King's English Variation            2
# 11245         A20  English Opening: King's English Variation            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10537  gjjlb3Wr   True  1.397467e+12  1.397469e+12     86         resign
# 11246  gjjlb3Wr   True  1.397467e+12  1.397469e+12     86         resign
#
#       winner increment_code            white_id  white_rating black_id  \
# 10537  white          17+17  vladimir-kramnik-1          1693    join7
# 11246  white          17+17  vladimir-kramnik-1          1693    join7
#
#        black_rating                                              moves  \
# 10537          1477  e4 e5 Nf3 d6 d4 f6 dxe5 fxe5 Nc3 c6 Ng5 h5 Qf3...
# 11246          1477  e4 e5 Nf3 d6 d4 f6 dxe5 fxe5 Nc3 c6 Ng5 h5 Qf3...
#
#       opening_eco      opening_name  opening_ply
# 10537         C41  Philidor Defense            5
# 11246         C41  Philidor Defense            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10538  QzdedoG5   True  1.397461e+12  1.397462e+12     85         resign
# 11247  QzdedoG5   True  1.397461e+12  1.397462e+12     85         resign
#
#       winner increment_code white_id  white_rating            black_id  \
# 10538  white            8+5     toka          1664  vladimir-kramnik-1
# 11247  white            8+5     toka          1664  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# 10538          1706  e4 e6 d4 d5 e5 c5 c3 Nc6 Be3 Qb6 Qd2 cxd4 cxd4...
# 11247          1706  e4 e6 d4 d5 e5 c5 c3 Nc6 Be3 Qb6 Qd2 cxd4 cxd4...
#
#       opening_eco                       opening_name  opening_ply
# 10538         C02  French Defense: Advance Variation            8
# 11247         C02  French Defense: Advance Variation            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 10539  Zj6afVMU   True  1.397458e+12  1.397458e+12     70           mate
# 11248  Zj6afVMU   True  1.397458e+12  1.397458e+12     70           mate
#
#       winner increment_code white_id  white_rating            black_id  \
# 10539  black           10+5    chp-3          1500  vladimir-kramnik-1
# 11248  black           10+5    chp-3          1500  vladimir-kramnik-1
#
#        black_rating                                              moves  \
# ...
#              id  rated    created_at  last_move_at  turns victory_status  \
# 19648  YZO402Ei  False  1.503947e+12  1.503948e+12    120      outoftime
# 19758  YZO402Ei  False  1.503947e+12  1.503948e+12    120      outoftime
#
#       winner increment_code    white_id  white_rating   black_id  \
# 19648  black           10+0  dimitris22          1812  loukas435
# 19758  black           10+0  dimitris22          1812  loukas435
#
#        black_rating                                              moves  \
# 19648          1834  d4 f5 Nf3 g6 Bf4 d6 e3 Nf6 c4 Bg7 Nc3 Nfd7 Be2...
# 19758          1834  d4 f5 Nf3 g6 Bf4 d6 e3 Nf6 c4 Bg7 Nc3 Nfd7 Be2...
#
#       opening_eco   opening_name  opening_ply
# 19648         A80  Dutch Defense            2
# 19758         A80  Dutch Defense            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 18466  3cIFrSEh   True  1.504001e+12  1.504002e+12     48           mate
# 19889  3cIFrSEh   True  1.504001e+12  1.504002e+12     48           mate
#
#       winner increment_code       white_id  white_rating    black_id  \
# 18466  black           10+0  anastasia2009          1586  fourtwenty
# 19889  black           10+0  anastasia2009          1586  fourtwenty
#
#        black_rating                                              moves  \
# 18466          1558  e4 e5 Nf3 Nf6 d3 d5 exd5 Nxd5 d4 Bg4 Be2 exd4 ...
# 19889          1558  e4 e5 Nf3 Nf6 d3 d5 exd5 Nxd5 d4 Bg4 Be2 exd4 ...
#
#       opening_eco      opening_name  opening_ply
# 18466         C42  Petrov's Defense            4
# 19889         C42  Petrov's Defense            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 19035  M2ZlvyYy   True  1.503594e+12  1.503598e+12     71         resign
# 19980  M2ZlvyYy   True  1.503594e+12  1.503598e+12     71         resign
#
#       winner increment_code white_id  white_rating black_id  black_rating  \
# 19035  white          30+30     rb52          2057     ed84          1782
# 19980  white          30+30     rb52          2057     ed84          1782
#
#                                                    moves opening_eco  \
# 19035  d4 d5 c4 e6 Nc3 Nf6 Bg5 Be7 e3 h6 Bh4 O-O Nf3 ...         D55
# 19980  d4 d5 c4 e6 Nc3 Nf6 Bg5 Be7 e3 h6 Bh4 O-O Nf3 ...         D55
#
#                                             opening_name  opening_ply
# 19035  Queen's Gambit Declined: Neo-Orthodox Variatio...           13
# 19980  Queen's Gambit Declined: Neo-Orthodox Variatio...           13
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15019  d9X08Sof   True  1.504210e+12  1.504216e+12    103           draw
# 20003  d9X08Sof   True  1.504210e+12  1.504216e+12    103           draw
#
#       winner increment_code        white_id  white_rating    black_id  \
# 15019   draw          30+30  moistvonlipwig          2283  chess4life
# 20003   draw          30+30  moistvonlipwig          2283  chess4life
#
#        black_rating                                              moves  \
# 15019          2358  e4 c5 Nc3 e6 f4 d5 Nf3 dxe4 Nxe4 Nc6 b3 Nf6 Bd...
# 20003          2358  e4 c5 Nc3 e6 f4 d5 Nf3 dxe4 Nxe4 Nc6 b3 Nf6 Bd...
#
#       opening_eco              opening_name  opening_ply
# 15019         B23  Sicilian Defense: Closed            4
# 20003         B23  Sicilian Defense: Closed            4
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15020  Svkerj5v   True  1.503257e+12  1.503264e+12    109           draw
# 20004  Svkerj5v   True  1.503257e+12  1.503264e+12    109           draw
#
#       winner increment_code white_id  white_rating        black_id  \
# 15020   draw          30+30   god666          2214  moistvonlipwig
# 20004   draw          30+30   god666          2214  moistvonlipwig
#
#        black_rating                                              moves  \
# 15020          2286  f4 d5 Nf3 Nf6 e3 g6 Be2 Bg7 O-O O-O b3 Ne4 Ne5...
# 20004          2286  f4 d5 Nf3 Nf6 e3 g6 Be2 Bg7 O-O O-O b3 Ne4 Ne5...
#
#       opening_eco                   opening_name  opening_ply
# 15020         A03  Bird Opening: Dutch Variation            2
# 20004         A03  Bird Opening: Dutch Variation            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15021  A1BExYwf   True  1.502313e+12  1.502320e+12     92         resign
# 20005  A1BExYwf   True  1.502313e+12  1.502320e+12     92         resign
#
#       winner increment_code white_id  white_rating        black_id  \
# 15021  black          45+45      mn8          2232  moistvonlipwig
# 20005  black          45+45      mn8          2232  moistvonlipwig
#
#        black_rating                                              moves  \
# 15021          2272  e4 e5 Nf3 Nc6 Bc4 Nf6 d3 Bc5 O-O d6 c3 a5 a4 O...
# 20005          2272  e4 e5 Nf3 Nc6 Bc4 Nf6 d3 Bc5 O-O d6 c3 a5 a4 O...
#
#       opening_eco                               opening_name  opening_ply
# 15021         C50  Italian Game: Giuoco Pianissimo |  Normal            8
# 20005         C50  Italian Game: Giuoco Pianissimo |  Normal            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15022  vs4N1BEg   True  1.502222e+12  1.502228e+12     77         resign
# 20006  vs4N1BEg   True  1.502222e+12  1.502228e+12     77         resign
#
#       winner increment_code        white_id  white_rating    black_id  \
# 15022  white          30+30  moistvonlipwig          2264  wardsstone
# 20006  white          30+30  moistvonlipwig          2264  wardsstone
#
#        black_rating                                              moves  \
# 15022          2082  e4 e6 d4 d5 Nd2 Nf6 e5 Nfd7 Bd3 c5 c3 Nc6 Ne2 ...
# 20006          2082  e4 e6 d4 d5 Nd2 Nf6 e5 Nfd7 Bd3 c5 c3 Nc6 Ne2 ...
#
#       opening_eco                                       opening_name  \
# 15022         C06  French Defense: Tarrasch Variation |  Closed V...
# 20006         C06  French Defense: Tarrasch Variation |  Closed V...
#
#        opening_ply
# 15022           15
# 20006           15
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15023  xT3Qgs0d   True  1.502049e+12  1.502053e+12     76         resign
# 20007  xT3Qgs0d   True  1.502049e+12  1.502053e+12     76         resign
#
#       winner increment_code white_id  white_rating        black_id  \
# 15023  black          20+20   chgreg          1826  moistvonlipwig
# 20007  black          20+20   chgreg          1826  moistvonlipwig
#
#        black_rating                                              moves  \
# 15023          2262  e4 e5 Nc3 Nf6 g3 Bc5 Bg2 a5 Nge2 d6 h3 Nc6 d3 ...
# 20007          2262  e4 e5 Nc3 Nf6 g3 Bc5 Bg2 a5 Nge2 d6 h3 Nc6 d3 ...
#
#       opening_eco                   opening_name  opening_ply
# 15023         C26  Vienna Game: Mieses Variation            5
# 20007         C26  Vienna Game: Mieses Variation            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15024  S7dwSbNm   True  1.501953e+12  1.501953e+12     22         resign
# 20008  S7dwSbNm   True  1.501953e+12  1.501953e+12     22         resign
#
#       winner increment_code        white_id  white_rating black_id  \
# 15024  white          60+30  moistvonlipwig          2255   adulam
# 20008  white          60+30  moistvonlipwig          2255   adulam
#
#        black_rating                                              moves  \
# 15024          2008  e4 e5 Nf3 Nc6 Bc4 Be7 O-O Nf6 Re1 O-O d3 d5 ex...
# 20008          2008  e4 e5 Nf3 Nc6 Bc4 Be7 O-O Nf6 Re1 O-O d3 d5 ex...
#
#       opening_eco                     opening_name  opening_ply
# 15024         C50  Italian Game: Hungarian Defense            6
# 20008         C50  Italian Game: Hungarian Defense            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15025  58iZoULg   True  1.501783e+12  1.501788e+12     62         resign
# 20009  58iZoULg   True  1.501783e+12  1.501788e+12     62         resign
#
#       winner increment_code  white_id  white_rating        black_id  \
# 15025  black          30+30  neil1996          2007  moistvonlipwig
# 20009  black          30+30  neil1996          2007  moistvonlipwig
#
#        black_rating                                              moves  \
# 15025          2249  d4 Nf6 c4 e6 Nf3 b6 g3 Bb7 Bg2 Be7 Nc3 O-O O-O...
# 20009          2249  d4 Nf6 c4 e6 Nf3 b6 g3 Bb7 Bg2 Be7 Nc3 O-O O-O...
#
#       opening_eco                                       opening_name  \
# 15025         E17  Queen's Indian Defense: Classical Variation | ...
# 20009         E17  Queen's Indian Defense: Classical Variation | ...
#
#        opening_ply
# 15025           14
# 20009           14
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15026  lN9aZvfM   True  1.500957e+12  1.500959e+12     70         resign
# 20010  lN9aZvfM   True  1.500957e+12  1.500959e+12     70         resign
#
#       winner increment_code    white_id  white_rating        black_id  \
# 15026  black          20+20  kjfoster17          1801  moistvonlipwig
# 20010  black          20+20  kjfoster17          1801  moistvonlipwig
#
#        black_rating                                              moves  \
# 15026          2246  d4 Nf6 c4 e6 Nc3 Bb4 Qc2 c5 dxc5 Na6 a3 Bxc3+ ...
# 20010          2246  d4 Nf6 c4 e6 Nc3 Bb4 Qc2 c5 dxc5 Na6 a3 Bxc3+ ...
#
#       opening_eco                                       opening_name  \
# 15026         E38  Nimzo-Indian Defense: Classical Variation |  B...
# 20010         E38  Nimzo-Indian Defense: Classical Variation |  B...
#
#        opening_ply
# 15026            8
# 20010            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15027  gptZOHi9   True  1.500156e+12  1.500161e+12     63           draw
# 20011  gptZOHi9   True  1.500156e+12  1.500161e+12     63           draw
#
#       winner increment_code        white_id  white_rating   black_id  \
# 15027   draw          45+45  moistvonlipwig          2239  atrophied
# 20011   draw          45+45  moistvonlipwig          2239  atrophied
#
#        black_rating                                              moves  \
# 15027          2401  e4 c5 Nc3 Nc6 f4 g6 Nf3 Bg7 Bb5 Nd4 O-O Nxb5 N...
# 20011          2401  e4 c5 Nc3 Nc6 f4 g6 Nf3 Bg7 Bb5 Nd4 O-O Nxb5 N...
#
#       opening_eco                         opening_name  opening_ply
# 15027         B23  Sicilian Defense: Grand Prix Attack            5
# 20011         B23  Sicilian Defense: Grand Prix Attack            5
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15028  UrvIXmIz   True  1.500133e+12  1.500136e+12     58         resign
# 20012  UrvIXmIz   True  1.500133e+12  1.500136e+12     58         resign
#
#       winner increment_code white_id  white_rating        black_id  \
# 15028  black          20+20    rsava          1471  moistvonlipwig
# 20012  black          20+20    rsava          1471  moistvonlipwig
#
#        black_rating                                              moves  \
# 15028          2239  e4 e5 Nf3 Nc6 d4 exd4 Bc4 Bc5 c3 Nf6 e5 d5 exf...
# 20012          2239  e4 e5 Nf3 Nc6 d4 exd4 Bc4 Bc5 c3 Nf6 e5 d5 exf...
#
#       opening_eco                                       opening_name  \
# 15028         C53  Italian Game: Classical Variation |  Greco Gambit
# 20012         C53  Italian Game: Classical Variation |  Greco Gambit
#
#        opening_ply
# 15028           12
# 20012           12
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15029  Uk0pZCRR   True  1.499532e+12  1.499541e+12     95         resign
# 20013  Uk0pZCRR   True  1.499532e+12  1.499541e+12     95         resign
#
#       winner increment_code   white_id  white_rating        black_id  \
# 15029  black          45+45  kferapont          2094  moistvonlipwig
# 20013  black          45+45  kferapont          2094  moistvonlipwig
#
#        black_rating                                              moves  \
# 15029          2228  e4 e5 Nf3 Nc6 Bb5 g6 d4 exd4 Bxc6 dxc6 Qxd4 Qx...
# 20013          2228  e4 e5 Nf3 Nc6 Bb5 g6 d4 exd4 Bxc6 dxc6 Qxd4 Qx...
#
#       opening_eco                   opening_name  opening_ply
# 15029         C60  Ruy Lopez: Fianchetto Defense            6
# 20013         C60  Ruy Lopez: Fianchetto Defense            6
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15030  ZhZm1ol9   True  1.498871e+12  1.498879e+12    109           draw
# 20014  ZhZm1ol9   True  1.498871e+12  1.498879e+12    109           draw
#
#       winner increment_code        white_id  white_rating black_id  \
# 15030   draw          45+45  moistvonlipwig          2229      mn8
# 20014   draw          45+45  moistvonlipwig          2229      mn8
#
#        black_rating                                              moves  \
# 15030          2220  e4 e5 Nf3 Nc6 Bc4 Bc5 c3 Nf6 d4 exd4 cxd4 Bb4+...
# 20014          2220  e4 e5 Nf3 Nc6 Bc4 Bc5 c3 Nf6 d4 exd4 cxd4 Bb4+...
#
#       opening_eco                                       opening_name  \
# 15030         C54  Italian Game: Classical Variation |  Greco Gam...
# 20014         C54  Italian Game: Classical Variation |  Greco Gam...
#
#        opening_ply
# 15030           17
# 20014           17
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15031  fpqjttDx   True  1.497663e+12  1.497664e+12     42         resign
# 20015  fpqjttDx   True  1.497663e+12  1.497664e+12     42         resign
#
#       winner increment_code        white_id  white_rating        black_id  \
# 15031  black           7+30  waltersafarian          2162  moistvonlipwig
# 20015  black           7+30  waltersafarian          2162  moistvonlipwig
#
#        black_rating                                              moves  \
# 15031          2214  d4 Nf6 c4 e6 Nf3 Bb4+ Bd2 a5 e3 O-O Bd3 b6 O-O...
# 20015          2214  d4 Nf6 c4 e6 Nf3 Bb4+ Bd2 a5 e3 O-O Bd3 b6 O-O...
#
#       opening_eco                                 opening_name  opening_ply
# 15031         E11  Bogo-Indian Defense: Wade-Smyslov Variation            8
# 20015         E11  Bogo-Indian Defense: Wade-Smyslov Variation            8
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15032  lzPgCJCS   True  1.497660e+12  1.497663e+12    102         resign
# 20016  lzPgCJCS   True  1.497660e+12  1.497663e+12    102         resign
#
#       winner increment_code        white_id  white_rating        black_id  \
# 15032  black           7+30  moistvonlipwig          2236  waltersafarian
# 20016  black           7+30  moistvonlipwig          2236  waltersafarian
#
#        black_rating                                              moves  \
# 15032          2148  e4 g6 Nc3 Bg7 f4 c6 g3 d6 Bg2 e5 fxe5 dxe5 d3 ...
# 20016          2148  e4 g6 Nc3 Bg7 f4 c6 g3 d6 Bg2 e5 fxe5 dxe5 d3 ...
#
#       opening_eco    opening_name  opening_ply
# 15032         B06  Modern Defense            2
# 20016         B06  Modern Defense            2
#              id  rated    created_at  last_move_at  turns victory_status  \
# 15033  p391pBJv   True  1.497647e+12  1.497654e+12     97         resign
# 20017  p391pBJv   True  1.497647e+12  1.497654e+12     97         resign
#
#       winner increment_code   white_id  white_rating        black_id  \
# 15033  white          60+30  i9_4_2001          2268  moistvonlipwig
# 20017  white          60+30  i9_4_2001          2268  moistvonlipwig
#
#        black_rating                                              moves  \
# 15033          2254  e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 d5 exd5 Na5 Bb5+ c6 ...
# 20017          2254  e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 d5 exd5 Na5 Bb5+ c6 ...
#
#       opening_eco                                       opening_name  \
# 15033         C59  Italian Game: Two Knights Defense |  Steinitz ...
# 20017         C59  Italian Game: Two Knights Defense |  Steinitz ...
#
#        opening_ply
# 15033           17
# 20017           17

# %% [markdown]
# These duplicates are truly duplicates, they can be safely dropped.

# %%
# drop duplicates
games_df.drop_duplicates(inplace=True)
games_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# With the duplicates gone, the dataset is ready for some EDA.

# %% [markdown]
# ### Enhance the data

# %% [markdown]
# Let's begin by adding some columns:
#
# To enhance the data:
#
# * **"rating_difference"** (int) - the difference in rating between players, using "white_rating" and "black_rating"
# * **"avg_rating"** (float) - the average rating between players, using "white_rating" and "black_rating"
#
# To better group the data:
#
# * **"opening"** (string) - a more generalized opening, using "opening_name"
# * **"skill_level"** (string) - the category of the players' rating ("beginner", "intermediate", "advanced", "expert, "master"), using "avg_rating"
# * **"time_control"** (string) - the category of time increment ("bullet", "blitz", "rapid", "classic"), using "increment_code"

# %%
# add rating_difference column by determining difference between white's and black's ratings
games_df['rating_difference'] = games_df['white_rating'] - games_df['black_rating']

# add avg_rating column by determining average between white's and black's ratings
games_df['avg_rating'] = (games_df['white_rating'] + games_df['black_rating']) / 2

# define a function to reduce the complexity of the opening name
def get_opening(opening_name):
    ''' This function will take a game instance from the games_df dataframe and return a shortened version of the opening_name
    
        parameters:
        opening_name - a row from the games_df dataframe

        returns:
        opening (string) - the generalized name of the opening played
        '''    
    return opening_name.split(':')[0]

# define a function to determine skill_level by grouping rating scores into categories
def get_skill_level(rating):
    ''' This function will take a game instance from the games_df dataframe and return a classifying string
    
        parameters:
        game - a row from the games_df dataframe
        
        returns:
        skill_level (string) - the rating classification for players in the game
    '''
    if rating <= 1400:
        return 'beginner'
    elif 1400 < rating <= 1600:
        return 'intermediate'
    elif 1600 < rating <= 1800:
        return 'advanced'
    else:
        return 'master'

# define a function to determine time control by grouping time increments into categories
def get_time_control(increment):
    ''' This function will take a game instance from the games_df dataframe and return a classifying string
    
        parameters:
        game - a row from the games_df dataframe
        
        returns:
        time_control (string) - the time control type for the game
    '''
    time = int(increment.split('+')[0])

    if time < 5:
        return 'bullet'
    elif 5 <= time < 10:
        return 'blitz'
    elif 10 <= time < 30:
        return 'rapid'
    else:
        return 'classic'
    
# create new columns by applying the above functions    
games_df['opening'] = games_df['opening_name'].apply(get_opening)
games_df['skill_level'] = games_df['avg_rating'].apply(get_skill_level)
games_df['time_control'] = games_df['increment_code'].apply(get_time_control)

# %% [markdown]
# ### Exploring the data

# %%
st.header('Total turns played in a game vs. Average rating of the players')

# generate a scatter plot of average player rating vs. total turns, colored by time control
px.scatter(games_df, x='avg_rating', y='turns', color='time_control',  title='Chess Game Total Turns vs. Average Player Rating',
    labels=dict(avg_rating='Average Player Rating', turns='Total Turns', time_control='Time Control'), opacity=.75)
# Out:
# 2022-11-03 12:32:09.495
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\joshg\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# observe most frequent openings
top_openings = games_df['opening'].value_counts()[:20]
print(top_openings)
# Out:
# Sicilian Defense           2527
# French Defense             1273
# Queen's Pawn Game          1039
# Italian Game                953
# King's Pawn Game            899
# Ruy Lopez                   833
# English Opening             715
# Scandinavian Defense        707
# Caro-Kann Defense           581
# Scotch Game                 455
# Queen's Gambit Declined     384
# Van't Kruijs Opening        363
# Four Knights Game           353
# Zukertort Opening           324
# Bishop's Opening            322
# Indian Game                 316
# Philidor Defense            267
# Queen's Gambit Refused      248
# Queen's Gambit Accepted     248
# Russian Game                247
# Name: opening, dtype: int64

# %%
st.header('Game End Conditions')

# show histogram of game outcomes, colored by skill level
px.histogram(games_df, x='victory_status', color='skill_level', title='Game End Conditions',
    labels=dict(victory_status='End Condition', skill_level='Skill Level', time_control='Time Control'))

# %%
st.header('Rating difference')
st.write('(positive values indicate white is higher rated)')

# create a checkbox to allow the use filter for games where 'rated' is True
rated_only = st.checkbox("Include only rated games")

# create a copy of our data that we can filter if the user chooses to do so
filter_df = games_df
if rated_only:
    filter_df = games_df[games_df['rated']]

# generate a histogram of the rating difference on the filtered data
fig = px.histogram(filter_df, x='rating_difference', nbins=250, range_x=[-500,500])

# use streamlit to display fig
st.write(fig)
fig

# %%
st.header('View winner color frequency by opening and skill level')

# generate a list of the 20 most popular openings
top_openings = games_df['opening'].value_counts()[:20]
openings = list(top_openings.index.unique())

# create an enhanced list with a 'Select all' option
openings_2 = openings[:]
openings_2.append('Select all')

# allow the user to select an opening, defaults on 'Select all'
opening = st.selectbox("Select an opening", openings_2, openings_2.index('Select all'))

# if the user choose 'Select all', we need to pass the whole list to our filter
if opening == 'Select all':
    opening = openings

# get a list of the skill levels available to choose from
skill_levels = list(games_df['skill_level'].unique())

# create an enhanced list with a 'Select all' option
skill_levels_2 = skill_levels[:]
skill_levels_2.append('Select all')

# allow the user to select a skill level, defaults on 'Select all'
skill_level = st.selectbox("Select a skill level", skill_levels_2, skill_levels_2.index('Select all'))

# if the user chooses 'Select all', we need to pass the whole list to our filter
if skill_level == 'Select all':
    skill_level = skill_levels

# filter our data per users choices
q_string = 'opening in @opening and skill_level in @skill_level'
filter_df = games_df.query(q_string)

# generate the histogram of winner color, in a consistent order with plotly express
fig = px.histogram(filter_df, x='winner', category_orders={'winner':['white','black','draw']})

# display the figure with streamlit
st.write(fig)
fig
